# %% [markdown]
# # <center>Python Basics<center/>
# <img height="60" width="120" src="https://www.python.org/static/img/python-logo-large.png?1414305901"></img>

# %% [markdown]
# # Table of contents
# <br/>
# <a href = "#6.-Variables">6. Variables</a><br/>
# <a href = "#7.-Data-Types">7. Data Types</a><br/>
# <a href = "#8.-Conversion-between-Datatypes">8. Conversion between Datatypes</a>

# %% [markdown]
# # 6. Variables

# %% [markdown]
# A variable is an alias given to a location in memory that is used to store some data (value).
#
# Each data point stored in the memory is given unique name to differentiate between different memory locations (and thus data points). <br/><b>The rules for writing a variable name is same as the rules for writing identifiers in Python.</b>
#
# We don't need to declare a variable before using it. In Python, we simply assign a value to a variable and it will exist. We don't even have to declare the <b>type</b> of the variable. This is handled internally according to the type of value we assign to the variable.
# <br/>
# <br/>

# %% [markdown]
# ### Variable assignements
# We use the assignment operator (=) to assign values to a variable

# %%
intergerNumber = 4
decimalNumber = 22.2
stringVariable = "StringValue"
print(intergerNumber, decimalNumber, stringVariable)
# Out:
# 4 22.2 StringValue

# %%
int integer = 4
print(integer)
# Out:
#   File "/tmp/ipykernel_2685/2519776195.py", line 1
#     int integer = 4
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Multiple assignements
# Use comma to seperate the variables and their corresponding values

# %%
intergerNumber, decimalNumber, stringVariable = 4, 22.2, "StringValue"
print(intergerNumber, decimalNumber, stringVariable)
# Out:
# 4 22.2 StringValue

# %% [markdown]
# To initialize multiple variables with same value use 1 assignment

# %%
variable1=variable2=variable3 = " All variable assigned same value "
print(variable1,variable2,variable3)
# Out:
#  All variable assigned same value   All variable assigned same value   All variable assigned same value

# %% [markdown]
# ### Storage Locations

# %%
print(id(intergerNumber))               #print address of variable: 'intergerNumber'
# Out:
# 11645448

# %%
intNumber2= 3
print(id(intNumber2))               #print address of variable: 'intNumber2'
# Out:
# 11645416

# %%
intNumber3= 3
print(id(intNumber3))
# Out:
# 11645416

# %%
print(id(decimalNumber))               #print address of variable: 'decimalNumber'
# Out:
# 137735457106288

# %%
decimanNum2 = 22.2
print(id(decimanNum2))               #print address of variable: 'decimanNum2'
# Out:
# 137735457108656

# %% [markdown]
# <b>interger1</b> and <b>interger2</b> points to same memory location in the below example

# %%
interger1 = 10
interger2 = 10

print(id(interger1))
print(id(interger2))
# Out:
# 11645640
# 11645640

# %%
import sys
print(sys.getsizeof(interger1)) # to check memory size of occupancy given variable
print(sys.getsizeof(interger2))
# Out:
# 28
# 28

# %%
integer3= 10000
integer4=10000
print(id(integer3))
print(id(integer4))
print(sys.getsizeof(integer3))
# Out:
# 137735155950384
# 137735155951376
# 28

# %%
integer5= 2193728473879289273823
print(id(integer5))
print(sys.getsizeof(integer5))
# Out:
# 137735156439616
# 36

# %% [markdown]
# # 7. Data Types

# %% [markdown]
# Every value in Python has a datatype. Since everything is an object in Python programming, data types are actually classes and variables are instance (object) of these classes.
# <br/><br/>
# Below are few of the commonly used data types<br/>

# %% [markdown]
# ### Python Numbers

# %% [markdown]
# <b>Integers, floating point numbers and complex numbers</b>
# falls under Python numbers category. They are defined as int, float and complex class in Python.
#
# We can use the <b>type()</b> function to know which class a variable or a value belongs to <br/> and the <b>isinstance()</b> function to check if an object belongs to a particular class.

# %%
data1 = 12                               # integer data type
print(data1, " is of type", type(data1))
# Out:
# 5  is of type <class 'int'>

# %%
data2 = 12.5                            # float data type
print(data2, " is of type", type(data2))
# Out:
# 2.5  is of type <class 'float'>

# %%
data3 = 100 + 20j
print(data3, " is of type", type(data3))
# Out:
# (100+20j)  is of type <class 'complex'>

# %%
data3 = 100 + 20j                          #data type is changed to complex number
print(data3, " is complex number?", isinstance(data3, complex)) # boolean value --> (True/False)
# Out:
# (100+20j)  is complex number? True

# %%
print(isinstance(data3, complex))
# Out:
# True

# %% [markdown]
# ### Boolean

# %% [markdown]
# Boolean represents True or False values

# %%
booleanVariable = True                          # 'booleanVariable' is a boolean type & True is a keyword
print(type(booleanVariable))
# Out:
# <class 'bool'>

# %%
print(isinstance(booleanVariable, bool))
# Out:
# True

# %% [markdown]
# ### Python Strings

# %% [markdown]
# String is sequence of Unicode characters. We can use single quotes or double quotes to represent strings. <br/>
# Multi-line strings can be denoted using triple quotes(single/double), <b>''' or """. </b><br/>
#
# A string in Python consists of a series or <u>sequence of characters</u> - <b>letters, numbers, and special characters.</b>
#
# Strings can be indexed - often synonymously called subscripted as well.
#
# The first character of a string has the index 0.

# %%
stringVariable = "This is a string variable"
print('stringVariable is : ',stringVariable)
print('First character in stringVariable is : ',stringVariable[0])
# Out:
# stringVariable is :  This is a string variable
# First character in stringVariable is :  T

# %%
print(type(stringVariable))
# Out:
# <class 'str'>

# %%
# Syntax to print a range slice in string strName[st_idx : end_idx : step_size] # step_size also determines direction.
#st_idx is inclusve , end_idx is exclusive
stringVariable[8]
# Out:
# 'a'

# %%
# Start and 6th Index and print till last index. Suppose we do not know what is the end index of the string.
stringVariable[6:] # No need to provide the end index.

# %%
# Start from the begining and print till 14th index
stringVariable[:15] # No need to provide the start index.
# Out:
# 'This is a strin'

# %%
# Slicing of String variable
print(stringVariable[0:12]) # Print from 0th index to 11th index.
print(stringVariable[:7])
print(stringVariable[5:])
# Out:
# This is a st
# This is
# is a string variable

# %%
stringVariable[0:1000]
# Out:
# 'This is a string variable'

# %%
# Want to print the string backwards
print(stringVariable[::3]) # 3rd parameter is step size.
# Out:
# Tss rgaae

# %%
# Print the String in reverse order from (6th last index )to the 1st index
stringVariable[::-6] # We are printing ever 6th elemebt backwards
print(stringVariable[-6::-1])
# Out:
# rav gnirts a si sihT

# %%
print(stringVariable[2:5:-1])

# %%
stringVariable[12:5:-1]
# Out:
# 'rts a s'

# %%
stringVariable[::-2] # start index=0, end_index= last index, step_size = +2 --> Print every 2nd element in direction left to right.
# Out:
# 'Ti sasrn aibe'

# %%
len(stringVariable)
# Out:
# 25

# %%
string1 = 'Hello World'
string1.append('Amit') # String is immutable.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2685/838550413.py in <cell line: 0>()
#       1 string1 = 'Hello World'
# ----> 2 string1.append('Amit')
#
# AttributeError: 'str' object has no attribute 'append'

# %% [markdown]
# ### Python List

# %% [markdown]
# List is an <u>ordered sequence</u> of items. It is one of the most used datatype in Python and is very flexible.
#
# All the items in a list do not need to be of the same type.
#
# Declaring a list is pretty straight forward. Items separated by commas are enclosed within square brackets <b>'[ ]'</b>.

# %%
myList = [1, 2.2, "ThirdElement",12,24,"More values"]
print(myList)           # Since python list is indexed , the order is maintained.
# Out:
# [1, 2.2, 'ThirdElement', 12, 24, 'More values']

# %%
print(myList[2])                     # Print an element based on its index. Index starts from 0
# Out:
# ThirdElement

# %% [markdown]
# Lists are mutable, which means, value of elements of a list can be changed.

# %%
myList[2] = "ElementThree"
print(myList)
# Out:
# [1, 2.2, 'ElementThree', 12, 24, 'More values']

# %%
myList.remove(2.2) # In remove function we directly provide the value to be removed
                            # Remove item from a particular index
print(myList)
# Out:
# [1, 'ElementThree', 12, 24, 'More values']

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2685/1773373466.py in <cell line: 0>()
# ----> 1 myList.remove[1]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
print(myList.pop(2) )   # Remove the item at index 2.                              # Remove item from a particular index
print(myList)
# Out:
# 12
# [1, 'ElementThree', 24, 'More values']

# %%
print(myList.pop() )   # If no index is provided, it will pop from the last.                         # Remove item from a particular index
print(myList)
# Out:
# More values
# [1, 'ElementThree', 24]

# %%
myList.append(2.2)                            # Add item at the last index
print(myList)
# Out:
# [1, 'ElementThree', 24, 'More values', 2.2]

# %%
list1= [1,2,3,4,5,56,7,8,89,10]
list2 = ['a','b']
list1.append(list2)

# %%
print(list1)
# Out:
# [1, 2, 3, 4, 5, 56, 7, 8, 89, 10, ['a', 'b']]

# %%
list1.extend(list2)

# %%
print(list1)
# Out:
# [1, 2, 3, 4, 5, 56, 7, 8, 89, 10, ['a', 'b'], 'a', 'b']

# %%
list1=[1,2,3,4,5,6]
list2= [8,7,6,5,4]
list1+list2
# Out:
# [1, 2, 3, 4, 5, 6, 8, 7, 6, 5, 4]

# %%
list1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list1.append(list2)

# %%
list1
# Out:
# [1, 2, 3, 4, 5, 6, [8, 7, 6, 5, 4]]

# %%
list1.extend(list2)
list1
# Out:
# [1, 2, 3, 4, 5, 6, [8, 7, 6, 5, 4], 8, 7, 6, 5, 4]

# %%
list2[1]=10

# %%
list1
# Out:
# [1, 2, 3, 4, 5, 6, [8, 10, 6, 5, 4], 8, 7, 6, 5, 4]

# %%
list1[6][2]
# Out:
# 6

# %%
# append happens by reference(memory Location)
# Extend is by value

# %% [markdown]
# ### Python Tuple

# %% [markdown]
# Tuple is an <u>ordered sequence</u> of items same as list. <br/>
# The only difference is that tuples are <u>immutable</u>. <b>Tuples once created cannot be modified</b>.
#
# Tuples are used to write-protect data and are usually faster than list as it cannot change dynamically.
#
# It is defined within parentheses <b>()</b> where items are separated by commas.

# %%
myTuple = (10,20,30,"Text")

# %%
print(myTuple[2])                 # Read elements by their corresponding index values
# Out:
# 30

# %%
myTuple[2] = 120
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-9dfd6922a533> in <module>()
# ----> 1 myTuple[2] = 120
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1=(1)
t2=("hi")
t3=(5.10)
t4=({'name':'dilip'})
print(type(t1),type(t2),type(t3),type(t4)) # if you dont give comma in the end .it will acts as data type that you given
# Out:
# <class 'int'> <class 'str'> <class 'float'> <class 'dict'>

# %%
t1=(1,)
t2=("hi",)
t3=(5.10,)
t4=({'name':'dilip'},)
print(type(t1),type(t2),type(t3),type(t4))
# Out:
# <class 'tuple'> <class 'tuple'> <class 'tuple'> <class 'tuple'>

# %% [markdown]
# ### Python Set

# %% [markdown]
# Set is an <u>unordered collection</u> of unique items. <br/>
# Set is defined by values separated by comma inside curly braces <b>{ }</b>. <br/>

# %%
mySet = {10, 20, 30, 40, 50}
print(mySet)
# Out:
# {50, 20, 40, 10, 30}

# %%
mySet = {10, 20, 20, 30, 30}       # Only unique values considered, duplicates removed automatically
print(mySet)
# Out:
# {10, 20, 30}

# %%
print(type(mySet))                 # Check the type of the variable
# Out:
# <class 'set'>

# %%
print(mySet[0])                    # Cannot print any particular element in a set because
                                   # it's an unorder collections of items
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2685/1639210337.py in <cell line: 0>()
# ----> 1 print(mySet[0])                    # Cannot print any particular element in a set because
#       2                                    # it's an unorder collections of items
#
# TypeError: 'set' object is not subscriptable

# %%
mySet.add(60)                      # Add a new element
print(mySet)
# Out:
# {10, 20, 30, 60}

# %%
# Add multiple elements
mySet.update([80, 90, 100])
print(mySet)
# Out:
# {100, 10, 80, 20, 90, 60, 30}

# %%
mySet.remove(100)

# %%
mySet
# Out:
# {10, 20, 30, 60, 80, 90}

# %% [markdown]
# ### Python Dictionary

# %% [markdown]
# <b>Dictionary</b> is an <u>unordered collection</u> of <b>key-value</b> pairs.
#
# It is generally used when we have a huge amount of data.<br/>
# Dictionaries are optimized for retrieving data. <br/>
# We must know the <b>key</b> to retrieve the <b>value</b>.
#
# In Python, dictionaries are defined within curly braces <b>{}</b> <br/>
# with each item being a pair in the form <b>key:value</b>. <br/>
# <b>Key and value</b> can be of <u>any type</u>.

# %%
myDictionary = {'key1': "value1", 'key2': "value2", 'key3': "value3",}
print(myDictionary['key2'])
# Out:
# value2

# %% [markdown]
# <b>Update</b> a value in the dictionary

# %%
myDictionary['key2'] = "value2.2"
print(myDictionary)
# Out:
# {'key1': 'value1', 'key2': 'value2.2', 'key3': 'value3'}

# %% [markdown]
# <b>Add</b> a new key & value

# %%
myDictionary["key4"] = "value4"
print(myDictionary)
# Out:
# {'key1': 'value1', 'key2': 'value2.2', 'key3': 'value3', 'key4': 'value4'}

# %% [markdown]
# <b>Delete</b> Dictionary Elements

# %%
del myDictionary["key2"]
print(myDictionary)
# Out:
# {'key1': 'value1', 'key3': 'value3', 'key4': 'value4'}

# %%
myDictionary.keys()
# Out:
# dict_keys(['key1', 'key3', 'key4'])

# %%
myDictionary.values()
# Out:
# dict_values(['value1', 'value3', 'value4'])

# %%
list(myDictionary.items())[1]
# Out:
# ('key3', 'value3')

# %% [markdown]
# # 8. Conversion between Datatypes

# %% [markdown]
# To convert between different data types use different type conversion functions like <b>int(), float(), str()</b> etc.

# %%
int(5.5)
# Out:
# 5

# %%
float(5)
# Out:
# 5.0

# %% [markdown]
# Conversion to and from string must contain compatible values.

# %%
str(5)
# Out:
# '5'

# %%
int(float('5.5'))
# Out:
# 5

# %%
str(5.5)
# Out:
# '5.5'

# %%
int('5')
# Out:
# 5

# %%
int('5.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-66621aca2009> in <module>()
# ----> 1 int('5.5')
#
# ValueError: invalid literal for int() with base 10: '5.5'

# %%
float('5.5')
# Out:
# 5.5

# %%
float('5')
# Out:
# 5.0

# %%
int(float('a10')) # Text can never be converted to Integer directly
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2685/405275934.py in <cell line: 0>()
# ----> 1 int(float('a10')) # Text can never be converted to Integer directly
#
# ValueError: could not convert string to float: 'a10'

# %%
myNewString = 'text1 '+ 20 + ' text2'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-a34dc682c656> in <module>()
# ----> 1 myNewString = 'text1 '+ 20 + ' text2'
#
# TypeError: must be str, not int

# %%
myNewString = 'text1 '+ str(20) + ' text2'
print(myNewString)
# Out:
# text1 20 text2

# %% [markdown]
# Convert,<br/>
# 1> list to set<br/>
# 2> String to list

# %%
# 1> list to set
myList1 = ['a','b','c','c']
print(myList1)
print(type(myList1))
mySet1 = set(myList1)
print(type(mySet1))
print(mySet1)
# Out:
# ['a', 'b', 'c', 'c']
# <class 'list'>
# <class 'set'>
# {'c', 'b', 'a'}

# %%
# 2> String to list
myString1 = 'This is string to list'
print(type(myString1))

strToList = list(myString1)
print(type(strToList))
print(strToList)
# Out:
# <class 'str'>
# <class 'list'>
# ['T', 'h', 'i', 's', ' ', 'i', 's', ' ', 's', 't', 'r', 'i', 'n', 'g', ' ', 't', 'o', ' ', 'l', 'i', 's', 't']

# %%
My_rank=6.5
rank=int(My_rank)
print(rank)
str1=str(rank)
print(str1)
print(type(str1))
float1=float(str1)
print(float1)
# Out:
# 6
# 6
# <class 'str'>
# 6.0

# %%
newTuple = ("fruit",)
print(type(newTuple))
# Out:
# <class 'tuple'>
